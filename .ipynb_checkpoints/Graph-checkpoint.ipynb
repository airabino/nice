# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import time
import json
import numpy as np
import pandas as pd
import geopandas as gpd
import pickle as pkl
import networkx as nx
import matplotlib.pyplot as plt

from scipy.stats import rv_histogram

import nice
from nice.reload import deep_reload

# %%
deep_reload(nice)

rng = np.random.default_rng(26893751)

kw = {
    'rng': rng,
    'xlim': (0, 1e6),
    'ylim': (0, 1e6),
}

graph = nice.graph.nmu_graph(100, 3, **kw)

fig, ax = plt.subplots()

_ = nice.plot.plot_graph(graph, nodes = {}, edges = {}, ax = ax)

# %%
deep_reload(nice)

rng = np.random.default_rng(26893751)

kw = {
    'rng': rng,
    'xlim': (0, 1e6),
    'ylim': (0, 1e6),
}

graph = nice.graph.nlh_graph(100, 100e3, 300e3, **kw)

fig, ax = plt.subplots()

_ = nice.plot.plot_graph(graph, nodes = {}, edges = {}, ax = ax)

# %%
deep_reload(nice)

rng = np.random.default_rng(26893751)

kw = {
    'rng': rng,
    'xlim': (0, 1e6),
    'ylim': (0, 1e6),
}

graph = nice.graph.nmu_graph(100, 3, **kw)

conditions = [lambda e: e['distance'] <= 300e3]

apg = nice.graph.all_pairs_graph(graph, conditions)

fig, ax = plt.subplots()

_ = nice.plot.plot_graph(apg, nodes = {}, edges = {}, ax = ax)
